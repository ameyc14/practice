# %%
import pandas as pd
df=pd.read_csv('pokemon_data.csv')
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %%
# df=pd.read_csv('pokemon_data.csv')
# print(df.head(3))
# for index,row in df.iterrows():
#     print(index,row['Name'])
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
#read header 
# print(df.columns)
#read each column
# print(df['Name'][0:5])

# print(df[['Name','Type 1','HP']])

#print each row
# df.iloc[0:4]
# df.loc[df['Type 1']=='Fire']
# read specific locataion
# print(df.iloc[2,1])

# for index,row in df.iterrows():
#     print(index,row['Name'])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
# df.describe()
# df.sort_values('Name', ascending=False)
df.sort_values(['Type 1', 'HP'],ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 520      116       56     95           4      False
# 698      135      105    100           5      False
# 231       40       95     85           2      False
# 232       40      105     75           2      False
# 678      100       60    145           5      False
# ..       ...      ...    ...         ...        ...
# 106       25       25     50           1      False
# 125       70       25     60           1      False
# 129       70       55     85           1      False
# 139       15       20     80           1      False
# 381       10       55     80           3      False
#
# [800 rows x 12 columns]

# %%
# adding columns
# df['Total']= df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Speed']
# df['Total']= df.iloc[:,4:10].sum(axis=1)
# df=df.drop(columns=['Total'])
# moving total before HP
cols=list(df.columns)
df=df[cols[0:5]+[cols[-1]]+cols[5:12]]

# df[['Total', 'Hp', 'Defense']]

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  Generation  Legendary  HP  \
# 0  1              Bulbasaur  Grass  Poison    318           1      False  45
# 1  2                Ivysaur  Grass  Poison    405           1      False  60
# 2  3               Venusaur  Grass  Poison    525           1      False  80
# 3  3  VenusaurMega Venusaur  Grass  Poison    625           1      False  80
# 4  4             Charmander   Fire     NaN    309           1      False  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      49       49       65       65     45
# 1      62       63       80       80     60
# 2      82       83      100      100     80
# 3     100      123      122      120     80
# 4      52       43       60       50     65

# %%
# df.to_csv('modified.csv',index=False)
df.to_excel('modified.xlsx',index=False)
# df.to_csv('modified.txt',index=False, sep='\t')

# %%
#Filtering Data

# %%
#Filtering Data

# %%
#Filtering Data

# %%
# df.loc[df['Type 1'] == 'Grass']
# df.loc[(df['Type 1']=='Grass') & ( df['Type 2'] == 'Poison')]
# df.loc[(df['Type 1']=='Grass') | ( df['Type 2'] == 'Poison')]
new_df=df.loc[(df['Type 1']=='Grass') & ( df['Type 2'] == 'Poison') & (df['HP']> 60)]
# new_df.to_csv('filtered.csv')
# new_df= new_df.reset_index()
new_df.reset_index(drop=True , inplace=True)
new_df
# Out:
#      #                   Name Type 1  Type 2  Total  Generation  Legendary  \
# 0    3               Venusaur  Grass  Poison    525           1      False
# 1    3  VenusaurMega Venusaur  Grass  Poison    625           1      False
# 2   45              Vileplume  Grass  Poison    490           1      False
# 3   70             Weepinbell  Grass  Poison    390           1      False
# 4   71             Victreebel  Grass  Poison    490           1      False
# 5  590                Foongus  Grass  Poison    294           5      False
# 6  591              Amoonguss  Grass  Poison    464           5      False
#
#     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0   80      82       83      100      100     80
# 1   80     100      123      122      120     80
# 2   75      80       85      110       90     50
# 3   65      90       50       85       45     55
# 4   80     105       65      100       70     70
# 5   69      55       45       55       55     15
# 6  114      85       70       85       80     30

# %%
# df.loc[df['Name'].str.contains('Mega')]
# df.loc[~df['Name'].str.contains('Mega')]
import re  #regex
# df.loc[df['Type 1'].str.contains('fire|glass', flags=re.I, regex=True)]

# df.loc[df['Name'].str.contains('^pi[a-z]*' , regex=True , flags=re.I)]
df.loc[df['Type 1'] =='Flamer' , 'Type 1'] = 'Fire'
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Generation  \
# 0      1              Bulbasaur    Grass  Poison    318           1
# 1      2                Ivysaur    Grass  Poison    405           1
# 2      3               Venusaur    Grass  Poison    525           1
# 3      3  VenusaurMega Venusaur    Grass  Poison    625           1
# 4      4             Charmander     Fire     NaN    309           1
# ..   ...                    ...      ...     ...    ...         ...
# 795  719                Diancie     Rock   Fairy    600           6
# 796  719    DiancieMega Diancie     Rock   Fairy    700           6
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600           6
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680           6
# 799  721              Volcanion     Fire   Water    600           6
#
#      Legendary  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0        False  45      49       49       65       65     45
# 1        False  60      62       63       80       80     60
# 2        False  80      82       83      100      100     80
# 3        False  80     100      123      122      120     80
# 4        False  39      52       43       60       50     65
# ..         ...  ..     ...      ...      ...      ...    ...
# 795       True  50     100      150      100      150     50
# 796       True  50     160      110      160      110    110
# 797       True  80     110       60      150      130     70
# 798       True  80     160       60      170      130     80
# 799       True  80     110      120      130       90     70
#
# [800 rows x 13 columns]

# %%
#Aggregate statistics (GroupBy)

# %%
#Aggregate statistics (GroupBy)

# %%
#Aggregate statistics (GroupBy)

# %%
# df=pd.read_csv('modified.csv')
# df.groupby(df['Type 1']).mean(numeric_only=True)
df['count']=1
df.groupby(df['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
#Working with large amounts of data

# %%
#Working with large amounts of data

# %%
#Working with large amounts of data

# %%
for df in pd.read_csv('modified.csv', chunksize=50):

    print(" chunk df")
    print(df)
# Out:
#  chunk df
#      #                       Name    Type 1  Type 2  Total  Generation  \
# 0    1                  Bulbasaur     Grass  Poison    318           1
# 1    2                    Ivysaur     Grass  Poison    405           1
# 2    3                   Venusaur     Grass  Poison    525           1
# 3    3      VenusaurMega Venusaur     Grass  Poison    625           1
# 4    4                 Charmander      Fire     NaN    309           1
# 5    5                 Charmeleon      Fire     NaN    405           1
# 6    6                  Charizard      Fire  Flying    534           1
# 7    6  CharizardMega Charizard X      Fire  Dragon    634           1
# 8    6  CharizardMega Charizard Y      Fire  Flying    634           1
# 9    7                   Squirtle     Water     NaN    314           1
# 10   8                  Wartortle     Water     NaN    405           1
# 11   9                  Blastoise     Water     NaN    530           1
# 12   9    BlastoiseMega Blastoise     Water     NaN    630           1
# 13  10                   Caterpie       Bug     NaN    195           1
# 14  11                    Metapod       Bug     NaN    205           1
# 15  12                 Butterfree       Bug  Flying    395           1
# 16  13                     Weedle       Bug  Poison    195           1
# 17  14                     Kakuna       Bug  Poison    205           1
# 18  15                   Beedrill       Bug  Poison    395           1
# 19  15      BeedrillMega Beedrill       Bug  Poison    495           1
# 20  16                     Pidgey    Normal  Flying    251           1
# 21  17                  Pidgeotto    Normal  Flying    349           1
# 22  18                    Pidgeot    Normal  Flying    479           1
# 23  18        PidgeotMega Pidgeot    Normal  Flying    579           1
# 24  19                    Rattata    Normal     NaN    253           1
# 25  20                   Raticate    Normal     NaN    413           1
# 26  21                    Spearow    Normal  Flying    262           1
# 27  22                     Fearow    Normal  Flying    442           1
# 28  23                      Ekans    Poison     NaN    288           1
# 29  24                      Arbok    Poison     NaN    438           1
# 30  25                    Pikachu  Electric     NaN    320           1
# 31  26                     Raichu  Electric     NaN    485           1
# 32  27                  Sandshrew    Ground     NaN    300           1
# 33  28                  Sandslash    Ground     NaN    450           1
# 34  29           Nidoran (Female)    Poison     NaN    275           1
# 35  30                   Nidorina    Poison     NaN    365           1
# 36  31                  Nidoqueen    Poison  Ground    505           1
# 37  32             Nidoran (Male)    Poison     NaN    273           1
# 38  33                   Nidorino    Poison     NaN    365           1
# 39  34                   Nidoking    Poison  Ground    505           1
# 40  35                   Clefairy     Fairy     NaN    323           1
# 41  36                   Clefable     Fairy     NaN    483           1
# 42  37                     Vulpix      Fire     NaN    299           1
# 43  38                  Ninetales      Fire     NaN    505           1
# 44  39                 Jigglypuff    Normal   Fairy    270           1
# 45  40                 Wigglytuff    Normal   Fairy    435           1
# 46  41                      Zubat    Poison  Flying    245           1
# 47  42                     Golbat    Poison  Flying    455           1
# 48  43                     Oddish     Grass  Poison    320           1
# 49  44                      Gloom     Grass  Poison    395           1
#
#     Legendary   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0       False   45      49       49       65       65     45
# 1       False   60      62       63       80       80     60
# 2       False   80      82       83      100      100     80
# 3       False   80     100      123      122      120     80
# 4       False   39      52       43       60       50     65
# 5       False   58      64       58       80       65     80
# 6       False   78      84       78      109       85    100
# 7       False   78     130      111      130       85    100
# 8       False   78     104       78      159      115    100
# 9       False   44      48       65       50       64     43
# 10      False   59      63       80       65       80     58
# 11      False   79      83      100       85      105     78
# 12      False   79     103      120      135      115     78
# 13      False   45      30       35       20       20     45
# 14      False   50      20       55       25       25     30
# 15      False   60      45       50       90       80     70
# 16      False   40      35       30       20       20     50
# 17      False   45      25       50       25       25     35
# 18      False   65      90       40       45       80     75
# 19      False   65     150       40       15       80    145
# 20      False   40      45       40       35       35     56
# 21      False   63      60       55       50       50     71
# 22      False   83      80       75       70       70    101
# 23      False   83      80       80      135       80    121
# 24      False   30      56       35       25       35     72
# 25      False   55      81       60       50       70     97
# 26      False   40      60       30       31       31     70
# 27      False   65      90       65       61       61    100
# 28      False   35      60       44       40       54     55
# 29      False   60      85       69       65       79     80
# 30      False   35      55       40       50       50     90
# 31      False   60      90       55       90       80    110
# 32      False   50      75       85       20       30     40
# 33      False   75     100      110       45       55     65
# 34      False   55      47       52       40       40     41
# 35      False   70      62       67       55       55     56
# 36      False   90      92       87       75       85     76
# 37      False   46      57       40       40       40     50
# 38      False   61      72       57       55       55     65
# 39      False   81     102       77       85       75     85
# 40      False   70      45       48       60       65     35
# 41      False   95      70       73       95       90     60
# 42      False   38      41       40       50       65     65
# 43      False   73      76       75       81      100    100
# 44      False  115      45       20       45       25     20
# 45      False  140      70       45       85       50     45
# 46      False   40      45       35       30       40     55
# 47      False   75      80       70       65       75     90
# 48      False   45      50       55       75       65     30
# 49      False   60      65       70       85       75     40
#  chunk df
#      #                   Name    Type 1    Type 2  Total  Generation  \
# 50  45              Vileplume     Grass    Poison    490           1
# 51  46                  Paras       Bug     Grass    285           1
# 52  47               Parasect       Bug     Grass    405           1
# 53  48                Venonat       Bug    Poison    305           1
# 54  49               Venomoth       Bug    Poison    450           1
# 55  50                Diglett    Ground       NaN    265           1
# 56  51                Dugtrio    Ground       NaN    405           1
# 57  52                 Meowth    Normal       NaN    290           1
# 58  53                Persian    Normal       NaN    440           1
# 59  54                Psyduck     Water       NaN    320           1
# 60  55                Golduck     Water       NaN    500           1
# 61  56                 Mankey  Fighting       NaN    305           1
# 62  57               Primeape  Fighting       NaN    455           1
# 63  58              Growlithe      Fire       NaN    350           1
# 64  59               Arcanine      Fire       NaN    555           1
# 65  60                Poliwag     Water       NaN    300           1
# 66  61              Poliwhirl     Water       NaN    385           1
# 67  62              Poliwrath     Water  Fighting    510           1
# 68  63                   Abra   Psychic       NaN    310           1
# 69  64                Kadabra   Psychic       NaN    400           1
# 70  65               Alakazam   Psychic       NaN    500           1
# 71  65  AlakazamMega Alakazam   Psychic       NaN    590           1
# 72  66                 Machop  Fighting       NaN    305           1
# 73  67                Machoke  Fighting       NaN    405           1
# 74  68                Machamp  Fighting       NaN    505           1
# 75  69             Bellsprout     Grass    Poison    300           1
# 76  70             Weepinbell     Grass    Poison    390           1
# 77  71             Victreebel     Grass    Poison    490           1
# 78  72              Tentacool     Water    Poison    335           1
# 79  73             Tentacruel     Water    Poison    515           1
# 80  74                Geodude      Rock    Ground    300           1
# 81  75               Graveler      Rock    Ground    390           1
# 82  76                  Golem      Rock    Ground    495           1
# 83  77                 Ponyta      Fire       NaN    410           1
# 84  78               Rapidash      Fire       NaN    500           1
# 85  79               Slowpoke     Water   Psychic    315           1
# 86  80                Slowbro     Water   Psychic    490           1
# 87  80    SlowbroMega Slowbro     Water   Psychic    590           1
# 88  81              Magnemite  Electric     Steel    325           1
# 89  82               Magneton  Electric     Steel    465           1
# 90  83             Farfetch'd    Normal    Flying    352           1
# 91  84                  Doduo    Normal    Flying    310           1
# 92  85                 Dodrio    Normal    Flying    460           1
# 93  86                   Seel     Water       NaN    325           1
# 94  87                Dewgong     Water       Ice    475           1
# 95  88                 Grimer    Poison       NaN    325           1
# 96  89                    Muk    Poison       NaN    500           1
# 97  90               Shellder     Water       NaN    305           1
# 98  91               Cloyster     Water       Ice    525           1
# 99  92                 Gastly     Ghost    Poison    310           1
#
#     Legendary   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 50      False   75      80       85      110       90     50
# 51      False   35      70       55       45       55     25
# 52      False   60      95       80       60       80     30
# 53      False   60      55       50       40       55     45
# 54      False   70      65       60       90       75     90
# 55      False   10      55       25       35       45     95
# 56      False   35      80       50       50       70    120
# 57      False   40      45       35       40       40     90
# 58      False   65      70       60       65       65    115
# 59      False   50      52       48       65       50     55
# 60      False   80      82       78       95       80     85
# 61      False   40      80       35       35       45     70
# 62      False   65     105       60       60       70     95
# 63      False   55      70       45       70       50     60
# 64      False   90     110       80      100       80     95
# 65      False   40      50       40       40       40     90
# 66      False   65      65       65       50       50     90
# 67      False   90      95       95       70       90     70
# 68      False   25      20       15      105       55     90
# 69      False   40      35       30      120       70    105
# 70      False   55      50       45      135       95    120
# 71      False   55      50       65      175       95    150
# 72      False   70      80       50       35       35     35
# 73      False   80     100       70       50       60     45
# 74      False   90     130       80       65       85     55
# 75      False   50      75       35       70       30     40
# 76      False   65      90       50       85       45     55
# 77      False   80     105       65      100       70     70
# 78      False   40      40       35       50      100     70
# 79      False   80      70       65       80      120    100
# 80      False   40      80      100       30       30     20
# 81      False   55      95      115       45       45     35
# 82      False   80     120      130       55       65     45
# 83      False   50      85       55       65       65     90
# 84      False   65     100       70       80       80    105
# 85      False   90      65       65       40       40     15
# 86      False   95      75      110      100       80     30
# 87      False   95      75      180      130       80     30
# 88      False   25      35       70       95       55     45
# 89      False   50      60       95      120       70     70
# 90      False   52      65       55       58       62     60
# 91      False   35      85       45       35       35     75
# 92      False   60     110       70       60       60    100
# 93      False   65      45       55       45       70     45
# 94      False   90      70       80       70       95     70
# 95      False   80      80       50       40       50     25
# 96      False  105     105       75       65      100     50
# 97      False   30      65      100       45       25     40
# 98      False   50      95      180       85       45     70
# 99      False   30      35       30      100       35     80
#  chunk df
#        #                       Name    Type 1   Type 2  Total  Generation  \
# 100   93                    Haunter     Ghost   Poison    405           1
# 101   94                     Gengar     Ghost   Poison    500           1
# 102   94          GengarMega Gengar     Ghost   Poison    600           1
# 103   95                       Onix      Rock   Ground    385           1
# 104   96                    Drowzee   Psychic      NaN    328           1
# 105   97                      Hypno   Psychic      NaN    483           1
# 106   98                     Krabby     Water      NaN    325           1
# 107   99                    Kingler     Water      NaN    475           1
# 108  100                    Voltorb  Electric      NaN    330           1
# 109  101                  Electrode  Electric      NaN    480           1
# 110  102                  Exeggcute     Grass  Psychic    325           1
# 111  103                  Exeggutor     Grass  Psychic    520           1
# 112  104                     Cubone    Ground      NaN    320           1
# 113  105                    Marowak    Ground      NaN    425           1
# 114  106                  Hitmonlee  Fighting      NaN    455           1
# 115  107                 Hitmonchan  Fighting      NaN    455           1
# 116  108                  Lickitung    Normal      NaN    385           1
# 117  109                    Koffing    Poison      NaN    340           1
# 118  110                    Weezing    Poison      NaN    490           1
# 119  111                    Rhyhorn    Ground     Rock    345           1
# 120  112                     Rhydon    Ground     Rock    485           1
# 121  113                    Chansey    Normal      NaN    450           1
# 122  114                    Tangela     Grass      NaN    435           1
# 123  115                 Kangaskhan    Normal      NaN    490           1
# 124  115  KangaskhanMega Kangaskhan    Normal      NaN    590           1
# 125  116                     Horsea     Water      NaN    295           1
# 126  117                     Seadra     Water      NaN    440           1
# 127  118                    Goldeen     Water      NaN    320           1
# 128  119                    Seaking     Water      NaN    450           1
# 129  120                     Staryu     Water      NaN    340           1
# 130  121                    Starmie     Water  Psychic    520           1
# 131  122                   Mr. Mime   Psychic    Fairy    460           1
# 132  123                    Scyther       Bug   Flying    500           1
# 133  124                       Jynx       Ice  Psychic    455           1
# 134  125                 Electabuzz  Electric      NaN    490           1
# 135  126                     Magmar      Fire      NaN    495           1
# 136  127                     Pinsir       Bug      NaN    500           1
# 137  127          PinsirMega Pinsir       Bug   Flying    600           1
# 138  128                     Tauros    Normal      NaN    490           1
# 139  129                   Magikarp     Water      NaN    200           1
# 140  130                   Gyarados     Water   Flying    540           1
# 141  130      GyaradosMega Gyarados     Water     Dark    640           1
# 142  131                     Lapras     Water      Ice    535           1
# 143  132                      Ditto    Normal      NaN    288           1
# 144  133                      Eevee    Normal      NaN    325           1
# 145  134                   Vaporeon     Water      NaN    525           1
# 146  135                    Jolteon  Electric      NaN    525           1
# 147  136                    Flareon      Fire      NaN    525           1
# 148  137                    Porygon    Normal      NaN    395           1
# 149  138                    Omanyte      Rock    Water    355           1
#
#      Legendary   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 100      False   45      50       45      115       55     95
# 101      False   60      65       60      130       75    110
# 102      False   60      65       80      170       95    130
# 103      False   35      45      160       30       45     70
# 104      False   60      48       45       43       90     42
# 105      False   85      73       70       73      115     67
# 106      False   30     105       90       25       25     50
# 107      False   55     130      115       50       50     75
# 108      False   40      30       50       55       55    100
# 109      False   60      50       70       80       80    140
# 110      False   60      40       80       60       45     40
# 111      False   95      95       85      125       65     55
# 112      False   50      50       95       40       50     35
# 113      False   60      80      110       50       80     45
# 114      False   50     120       53       35      110     87
# 115      False   50     105       79       35      110     76
# 116      False   90      55       75       60       75     30
# 117      False   40      65       95       60       45     35
# 118      False   65      90      120       85       70     60
# 119      False   80      85       95       30       30     25
# 120      False  105     130      120       45       45     40
# 121      False  250       5        5       35      105     50
# 122      False   65      55      115      100       40     60
# 123      False  105      95       80       40       80     90
# 124      False  105     125      100       60      100    100
# 125      False   30      40       70       70       25     60
# 126      False   55      65       95       95       45     85
# 127      False   45      67       60       35       50     63
# 128      False   80      92       65       65       80     68
# 129      False   30      45       55       70       55     85
# 130      False   60      75       85      100       85    115
# 131      False   40      45       65      100      120     90
# 132      False   70     110       80       55       80    105
# 133      False   65      50       35      115       95     95
# 134      False   65      83       57       95       85    105
# 135      False   65      95       57      100       85     93
# 136      False   65     125      100       55       70     85
# 137      False   65     155      120       65       90    105
# 138      False   75     100       95       40       70    110
# 139      False   20      10       55       15       20     80
# 140      False   95     125       79       60      100     81
# 141      False   95     155      109       70      130     81
# 142      False  130      85       80       85       95     60
# 143      False   48      48       48       48       48     48
# 144      False   55      55       50       45       65     55
# 145      False  130      65       60      110       95     65
# 146      False   65      65       60      110       95    130
# 147      False   65     130       60       95      110     65
# 148      False   65      60       70       85       75     40
# 149      False   35      40      100       90       55     35
#  chunk df
#        #                       Name    Type 1    Type 2  Total  Generation  \
# 150  139                    Omastar      Rock     Water    495           1
# 151  140                     Kabuto      Rock     Water    355           1
# 152  141                   Kabutops      Rock     Water    495           1
# 153  142                 Aerodactyl      Rock    Flying    515           1
# 154  142  AerodactylMega Aerodactyl      Rock    Flying    615           1
# 155  143                    Snorlax    Normal       NaN    540           1
# 156  144                   Articuno       Ice    Flying    580           1
# 157  145                     Zapdos  Electric    Flying    580           1
# 158  146                    Moltres      Fire    Flying    580           1
# 159  147                    Dratini    Dragon       NaN    300           1
# 160  148                  Dragonair    Dragon       NaN    420           1
# 161  149                  Dragonite    Dragon    Flying    600           1
# 162  150                     Mewtwo   Psychic       NaN    680           1
# 163  150        MewtwoMega Mewtwo X   Psychic  Fighting    780           1
# 164  150        MewtwoMega Mewtwo Y   Psychic       NaN    780           1
# 165  151                        Mew   Psychic       NaN    600           1
# 166  152                  Chikorita     Grass       NaN    318           2
# 167  153                    Bayleef     Grass       NaN    405           2
# 168  154                   Meganium     Grass       NaN    525           2
# 169  155                  Cyndaquil      Fire       NaN    309           2
# 170  156                    Quilava      Fire       NaN    405           2
# 171  157                 Typhlosion      Fire       NaN    534           2
# 172  158                   Totodile     Water       NaN    314           2
# 173  159                   Croconaw     Water       NaN    405           2
# 174  160                 Feraligatr     Water       NaN    530           2
# 175  161                    Sentret    Normal       NaN    215           2
# 176  162                     Furret    Normal       NaN    415           2
# 177  163                   Hoothoot    Normal    Flying    262           2
# 178  164                    Noctowl    Normal    Flying    442           2
# 179  165                     Ledyba       Bug    Flying    265           2
# 180  166                     Ledian       Bug    Flying    390           2
# 181  167                   Spinarak       Bug    Poison    250           2
# 182  168                    Ariados       Bug    Poison    390           2
# 183  169                     Crobat    Poison    Flying    535           2
# 184  170                   Chinchou     Water  Electric    330           2
# 185  171                    Lanturn     Water  Electric    460           2
# 186  172                      Pichu  Electric       NaN    205           2
# 187  173                     Cleffa     Fairy       NaN    218           2
# 188  174                  Igglybuff    Normal     Fairy    210           2
# 189  175                     Togepi     Fairy       NaN    245           2
# 190  176                    Togetic     Fairy    Flying    405           2
# 191  177                       Natu   Psychic    Flying    320           2
# 192  178                       Xatu   Psychic    Flying    470           2
# 193  179                     Mareep  Electric       NaN    280           2
# 194  180                    Flaaffy  Electric       NaN    365           2
# 195  181                   Ampharos  Electric       NaN    510           2
# 196  181      AmpharosMega Ampharos  Electric    Dragon    610           2
# 197  182                  Bellossom     Grass       NaN    490           2
# 198  183                     Marill     Water     Fairy    250           2
# 199  184                  Azumarill     Water     Fairy    420           2
#
#      Legendary   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 150      False   70      60      125      115       70     55
# 151      False   30      80       90       55       45     55
# 152      False   60     115      105       65       70     80
# 153      False   80     105       65       60       75    130
# 154      False   80     135       85       70       95    150
# 155      False  160     110       65       65      110     30
# 156       True   90      85      100       95      125     85
# 157       True   90      90       85      125       90    100
# 158       True   90     100       90      125       85     90
# 159      False   41      64       45       50       50     50
# 160      False   61      84       65       70       70     70
# 161      False   91     134       95      100      100     80
# 162       True  106     110       90      154       90    130
# 163       True  106     190      100      154      100    130
# 164       True  106     150       70      194      120    140
# 165      False  100     100      100      100      100    100
# 166      False   45      49       65       49       65     45
# 167      False   60      62       80       63       80     60
# 168      False   80      82      100       83      100     80
# 169      False   39      52       43       60       50     65
# 170      False   58      64       58       80       65     80
# 171      False   78      84       78      109       85    100
# 172      False   50      65       64       44       48     43
# 173      False   65      80       80       59       63     58
# 174      False   85     105      100       79       83     78
# 175      False   35      46       34       35       45     20
# 176      False   85      76       64       45       55     90
# 177      False   60      30       30       36       56     50
# 178      False  100      50       50       76       96     70
# 179      False   40      20       30       40       80     55
# 180      False   55      35       50       55      110     85
# 181      False   40      60       40       40       40     30
# 182      False   70      90       70       60       60     40
# 183      False   85      90       80       70       80    130
# 184      False   75      38       38       56       56     67
# 185      False  125      58       58       76       76     67
# 186      False   20      40       15       35       35     60
# 187      False   50      25       28       45       55     15
# 188      False   90      30       15       40       20     15
# 189      False   35      20       65       40       65     20
# 190      False   55      40       85       80      105     40
# 191      False   40      50       45       70       45     70
# 192      False   65      75       70       95       70     95
# 193      False   55      40       40       65       45     35
# 194      False   70      55       55       80       60     45
# 195      False   90      75       85      115       90     55
# 196      False   90      95      105      165      110     45
# 197      False   75      80       95       90      100     50
# 198      False   70      20       50       20       50     40
# 199      False  100      50       80       60       80     50
#  chunk df
#        #                     Name   Type 1    Type 2  Total  Generation  \
# 200  185                Sudowoodo     Rock       NaN    410           2
# 201  186                 Politoed    Water       NaN    500           2
# 202  187                   Hoppip    Grass    Flying    250           2
# 203  188                 Skiploom    Grass    Flying    340           2
# 204  189                 Jumpluff    Grass    Flying    460           2
# 205  190                    Aipom   Normal       NaN    360           2
# 206  191                  Sunkern    Grass       NaN    180           2
# 207  192                 Sunflora    Grass       NaN    425           2
# 208  193                    Yanma      Bug    Flying    390           2
# 209  194                   Wooper    Water    Ground    210           2
# 210  195                 Quagsire    Water    Ground    430           2
# 211  196                   Espeon  Psychic       NaN    525           2
# 212  197                  Umbreon     Dark       NaN    525           2
# 213  198                  Murkrow     Dark    Flying    405           2
# 214  199                 Slowking    Water   Psychic    490           2
# 215  200               Misdreavus    Ghost       NaN    435           2
# 216  201                    Unown  Psychic       NaN    336           2
# 217  202                Wobbuffet  Psychic       NaN    405           2
# 218  203                Girafarig   Normal   Psychic    455           2
# 219  204                   Pineco      Bug       NaN    290           2
# 220  205               Forretress      Bug     Steel    465           2
# 221  206                Dunsparce   Normal       NaN    415           2
# 222  207                   Gligar   Ground    Flying    430           2
# 223  208                  Steelix    Steel    Ground    510           2
# 224  208      SteelixMega Steelix    Steel    Ground    610           2
# 225  209                 Snubbull    Fairy       NaN    300           2
# 226  210                 Granbull    Fairy       NaN    450           2
# 227  211                 Qwilfish    Water    Poison    430           2
# 228  212                   Scizor      Bug     Steel    500           2
# 229  212        ScizorMega Scizor      Bug     Steel    600           2
# 230  213                  Shuckle      Bug      Rock    505           2
# 231  214                Heracross      Bug  Fighting    500           2
# 232  214  HeracrossMega Heracross      Bug  Fighting    600           2
# 233  215                  Sneasel     Dark       Ice    430           2
# 234  216                Teddiursa   Normal       NaN    330           2
# 235  217                 Ursaring   Normal       NaN    500           2
# 236  218                   Slugma     Fire       NaN    250           2
# 237  219                 Magcargo     Fire      Rock    410           2
# 238  220                   Swinub      Ice    Ground    250           2
# 239  221                Piloswine      Ice    Ground    450           2
# 240  222                  Corsola    Water      Rock    380           2
# 241  223                 Remoraid    Water       NaN    300           2
# 242  224                Octillery    Water       NaN    480           2
# 243  225                 Delibird      Ice    Flying    330           2
# 244  226                  Mantine    Water    Flying    465           2
# 245  227                 Skarmory    Steel    Flying    465           2
# 246  228                 Houndour     Dark      Fire    330           2
# 247  229                 Houndoom     Dark      Fire    500           2
# 248  229    HoundoomMega Houndoom     Dark      Fire    600           2
# 249  230                  Kingdra    Water    Dragon    540           2
#
#      Legendary   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 200      False   70     100      115       30       65     30
# 201      False   90      75       75       90      100     70
# 202      False   35      35       40       35       55     50
# 203      False   55      45       50       45       65     80
# 204      False   75      55       70       55       95    110
# 205      False   55      70       55       40       55     85
# 206      False   30      30       30       30       30     30
# 207      False   75      75       55      105       85     30
# 208      False   65      65       45       75       45     95
# 209      False   55      45       45       25       25     15
# 210      False   95      85       85       65       65     35
# 211      False   65      65       60      130       95    110
# 212      False   95      65      110       60      130     65
# 213      False   60      85       42       85       42     91
# 214      False   95      75       80      100      110     30
# 215      False   60      60       60       85       85     85
# 216      False   48      72       48       72       48     48
# 217      False  190      33       58       33       58     33
# 218      False   70      80       65       90       65     85
# 219      False   50      65       90       35       35     15
# 220      False   75      90      140       60       60     40
# 221      False  100      70       70       65       65     45
# 222      False   65      75      105       35       65     85
# 223      False   75      85      200       55       65     30
# 224      False   75     125      230       55       95     30
# 225      False   60      80       50       40       40     30
# 226      False   90     120       75       60       60     45
# 227      False   65      95       75       55       55     85
# 228      False   70     130      100       55       80     65
# 229      False   70     150      140       65      100     75
# 230      False   20      10      230       10      230      5
# 231      False   80     125       75       40       95     85
# 232      False   80     185      115       40      105     75
# 233      False   55      95       55       35       75    115
# 234      False   60      80       50       50       50     40
# 235      False   90     130       75       75       75     55
# 236      False   40      40       40       70       40     20
# 237      False   50      50      120       80       80     30
# 238      False   50      50       40       30       30     50
# 239      False  100     100       80       60       60     50
# 240      False   55      55       85       65       85     35
# 241      False   35      65       35       65       35     65
# 242      False   75     105       75      105       75     45
# 243      False   45      55       45       65       45     75
# 244      False   65      40       70       80      140     70
# 245      False   65      80      140       40       70     70
# 246      False   45      60       30       80       50     65
# 247      False   75      90       50      110       80     95
# 248      False   75      90       90      140       90    115
# 249      False   75      95       95       95       95     85
#  chunk df
#        #                     Name    Type 1    Type 2  Total  Generation  \
# 250  231                   Phanpy    Ground       NaN    330           2
# 251  232                  Donphan    Ground       NaN    500           2
# 252  233                 Porygon2    Normal       NaN    515           2
# 253  234                 Stantler    Normal       NaN    465           2
# 254  235                 Smeargle    Normal       NaN    250           2
# 255  236                  Tyrogue  Fighting       NaN    210           2
# 256  237                Hitmontop  Fighting       NaN    455           2
# 257  238                 Smoochum       Ice   Psychic    305           2
# 258  239                   Elekid  Electric       NaN    360           2
# 259  240                    Magby      Fire       NaN    365           2
# 260  241                  Miltank    Normal       NaN    490           2
# 261  242                  Blissey    Normal       NaN    540           2
# 262  243                   Raikou  Electric       NaN    580           2
# 263  244                    Entei      Fire       NaN    580           2
# 264  245                  Suicune     Water       NaN    580           2
# 265  246                 Larvitar      Rock    Ground    300           2
# 266  247                  Pupitar      Rock    Ground    410           2
# 267  248                Tyranitar      Rock      Dark    600           2
# 268  248  TyranitarMega Tyranitar      Rock      Dark    700           2
# 269  249                    Lugia   Psychic    Flying    680           2
# 270  250                    Ho-oh      Fire    Flying    680           2
# 271  251                   Celebi   Psychic     Grass    600           2
# 272  252                  Treecko     Grass       NaN    310           3
# 273  253                  Grovyle     Grass       NaN    405           3
# 274  254                 Sceptile     Grass       NaN    530           3
# 275  254    SceptileMega Sceptile     Grass    Dragon    630           3
# 276  255                  Torchic      Fire       NaN    310           3
# 277  256                Combusken      Fire  Fighting    405           3
# 278  257                 Blaziken      Fire  Fighting    530           3
# 279  257    BlazikenMega Blaziken      Fire  Fighting    630           3
# 280  258                   Mudkip     Water       NaN    310           3
# 281  259                Marshtomp     Water    Ground    405           3
# 282  260                 Swampert     Water    Ground    535           3
# 283  260    SwampertMega Swampert     Water    Ground    635           3
# 284  261                Poochyena      Dark       NaN    220           3
# 285  262                Mightyena      Dark       NaN    420           3
# 286  263                Zigzagoon    Normal       NaN    240           3
# 287  264                  Linoone    Normal       NaN    420           3
# 288  265                  Wurmple       Bug       NaN    195           3
# 289  266                  Silcoon       Bug       NaN    205           3
# 290  267                Beautifly       Bug    Flying    395           3
# 291  268                  Cascoon       Bug       NaN    205           3
# 292  269                   Dustox       Bug    Poison    385           3
# 293  270                    Lotad     Water     Grass    220           3
# 294  271                   Lombre     Water     Grass    340           3
# 295  272                 Ludicolo     Water     Grass    480           3
# 296  273                   Seedot     Grass       NaN    220           3
# 297  274                  Nuzleaf     Grass      Dark    340           3
# 298  275                  Shiftry     Grass      Dark    480           3
# 299  276                  Taillow    Normal    Flying    270           3
#
#      Legendary   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 250      False   90      60       60       40       40     40
# 251      False   90     120      120       60       60     50
# 252      False   85      80       90      105       95     60
# 253      False   73      95       62       85       65     85
# 254      False   55      20       35       20       45     75
# 255      False   35      35       35       35       35     35
# 256      False   50      95       95       35      110     70
# 257      False   45      30       15       85       65     65
# 258      False   45      63       37       65       55     95
# 259      False   45      75       37       70       55     83
# 260      False   95      80      105       40       70    100
# 261      False  255      10       10       75      135     55
# 262       True   90      85       75      115      100    115
# 263       True  115     115       85       90       75    100
# 264       True  100      75      115       90      115     85
# 265      False   50      64       50       45       50     41
# 266      False   70      84       70       65       70     51
# 267      False  100     134      110       95      100     61
# 268      False  100     164      150       95      120     71
# 269       True  106      90      130       90      154    110
# 270       True  106     130       90      110      154     90
# 271      False  100     100      100      100      100    100
# 272      False   40      45       35       65       55     70
# 273      False   50      65       45       85       65     95
# 274      False   70      85       65      105       85    120
# 275      False   70     110       75      145       85    145
# 276      False   45      60       40       70       50     45
# 277      False   60      85       60       85       60     55
# 278      False   80     120       70      110       70     80
# 279      False   80     160       80      130       80    100
# 280      False   50      70       50       50       50     40
# 281      False   70      85       70       60       70     50
# 282      False  100     110       90       85       90     60
# 283      False  100     150      110       95      110     70
# 284      False   35      55       35       30       30     35
# 285      False   70      90       70       60       60     70
# 286      False   38      30       41       30       41     60
# 287      False   78      70       61       50       61    100
# 288      False   45      45       35       20       30     20
# 289      False   50      35       55       25       25     15
# 290      False   60      70       50      100       50     65
# 291      False   50      35       55       25       25     15
# 292      False   60      50       70       50       90     65
# 293      False   40      30       30       40       50     30
# 294      False   60      50       50       60       70     50
# 295      False   80      70       70       90      100     70
# 296      False   40      40       50       30       30     30
# 297      False   70      70       40       60       40     60
# 298      False   90     100       60       90       60     80
# 299      False   40      55       30       30       30     85
#  chunk df
#        #                     Name    Type 1    Type 2  Total  Generation  \
# 300  277                  Swellow    Normal    Flying    430           3
# 301  278                  Wingull     Water    Flying    270           3
# 302  279                 Pelipper     Water    Flying    430           3
# 303  280                    Ralts   Psychic     Fairy    198           3
# 304  281                   Kirlia   Psychic     Fairy    278           3
# 305  282                Gardevoir   Psychic     Fairy    518           3
# 306  282  GardevoirMega Gardevoir   Psychic     Fairy    618           3
# 307  283                  Surskit       Bug     Water    269           3
# 308  284               Masquerain       Bug    Flying    414           3
# 309  285                Shroomish     Grass       NaN    295           3
# 310  286                  Breloom     Grass  Fighting    460           3
# 311  287                  Slakoth    Normal       NaN    280           3
# 312  288                 Vigoroth    Normal       NaN    440           3
# 313  289                  Slaking    Normal       NaN    670           3
# 314  290                  Nincada       Bug    Ground    266           3
# 315  291                  Ninjask       Bug    Flying    456           3
# 316  292                 Shedinja       Bug     Ghost    236           3
# 317  293                  Whismur    Normal       NaN    240           3
# 318  294                  Loudred    Normal       NaN    360           3
# 319  295                  Exploud    Normal       NaN    490           3
# 320  296                 Makuhita  Fighting       NaN    237           3
# 321  297                 Hariyama  Fighting       NaN    474           3
# 322  298                  Azurill    Normal     Fairy    190           3
# 323  299                 Nosepass      Rock       NaN    375           3
# 324  300                   Skitty    Normal       NaN    260           3
# 325  301                 Delcatty    Normal       NaN    380           3
# 326  302                  Sableye      Dark     Ghost    380           3
# 327  302      SableyeMega Sableye      Dark     Ghost    480           3
# 328  303                   Mawile     Steel     Fairy    380           3
# 329  303        MawileMega Mawile     Steel     Fairy    480           3
# 330  304                     Aron     Steel      Rock    330           3
# 331  305                   Lairon     Steel      Rock    430           3
# 332  306                   Aggron     Steel      Rock    530           3
# 333  306        AggronMega Aggron     Steel       NaN    630           3
# 334  307                 Meditite  Fighting   Psychic    280           3
# 335  308                 Medicham  Fighting   Psychic    410           3
# 336  308    MedichamMega Medicham  Fighting   Psychic    510           3
# 337  309                Electrike  Electric       NaN    295           3
# 338  310                Manectric  Electric       NaN    475           3
# 339  310  ManectricMega Manectric  Electric       NaN    575           3
# 340  311                   Plusle  Electric       NaN    405           3
# 341  312                    Minun  Electric       NaN    405           3
# 342  313                  Volbeat       Bug       NaN    400           3
# 343  314                 Illumise       Bug       NaN    400           3
# 344  315                  Roselia     Grass    Poison    400           3
# 345  316                   Gulpin    Poison       NaN    302           3
# 346  317                   Swalot    Poison       NaN    467           3
# 347  318                 Carvanha     Water      Dark    305           3
# 348  319                 Sharpedo     Water      Dark    460           3
# 349  319    SharpedoMega Sharpedo     Water      Dark    560           3
#
#      Legendary   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 300      False   60      85       60       50       50    125
# 301      False   40      30       30       55       30     85
# 302      False   60      50      100       85       70     65
# 303      False   28      25       25       45       35     40
# 304      False   38      35       35       65       55     50
# 305      False   68      65       65      125      115     80
# 306      False   68      85       65      165      135    100
# 307      False   40      30       32       50       52     65
# 308      False   70      60       62       80       82     60
# 309      False   60      40       60       40       60     35
# 310      False   60     130       80       60       60     70
# 311      False   60      60       60       35       35     30
# 312      False   80      80       80       55       55     90
# 313      False  150     160      100       95       65    100
# 314      False   31      45       90       30       30     40
# 315      False   61      90       45       50       50    160
# 316      False    1      90       45       30       30     40
# 317      False   64      51       23       51       23     28
# 318      False   84      71       43       71       43     48
# 319      False  104      91       63       91       73     68
# 320      False   72      60       30       20       30     25
# 321      False  144     120       60       40       60     50
# ...
# 663      55       40       45       40     60
# 664      85       70       75       70     40
# 665     115       80      105       80     50
# 666      55       55       85       55     30
# 667      75       75      125       95     40
# 668      30       55       65       55     20
# 669      40       60       95       60     55
# 670      55       90      145       90     80
# 671      87       60       30       40     57
# 672     117       70       40       50     67
# 673     147       90       60       70     97
# 674      70       40       60       40     40
# 675     110       80       70       80     50
# 676      50       30       95      135    105
# 677      40       85       40       65     25
# 678      70       40      100       60    145
# 679      66       84       81       99     32
# 680      85       50       55       50     65
# 681     125       60       95       60    105
# 682     120       90       60       90     48
# 683      74       50       35       50     35
# 684     124       80       55       80     55
# 685      85       70       40       40     60
# 686     125      100       60       70     70
# 687     110       95       40       95     55
# 688      83       50       37       50     60
# 689     123       75       57       75     80
# 690      55       75       45       65     60
# 691      65      105       55       95     80
# 692      97       66      105       66     65
# 693     109      112       48       48    109
# 694      65       50       45       50     38
# 695      85       70       65       70     58
# 696     105       90      125       90     98
# 697      85       55       50       55     60
# 698      60       65      135      105    100
# 699      90      129       90       72    108
#  chunk df
#        #                      Name    Type 1    Type 2  Total  Generation  \
# 700  639                 Terrakion      Rock  Fighting    580           5
# 701  640                  Virizion     Grass  Fighting    580           5
# 702  641   TornadusIncarnate Forme    Flying       NaN    580           5
# 703  641     TornadusTherian Forme    Flying       NaN    580           5
# 704  642  ThundurusIncarnate Forme  Electric    Flying    580           5
# 705  642    ThundurusTherian Forme  Electric    Flying    580           5
# 706  643                  Reshiram    Dragon      Fire    680           5
# 707  644                    Zekrom    Dragon  Electric    680           5
# 708  645   LandorusIncarnate Forme    Ground    Flying    600           5
# 709  645     LandorusTherian Forme    Ground    Flying    600           5
# 710  646                    Kyurem    Dragon       Ice    660           5
# 711  646        KyuremBlack Kyurem    Dragon       Ice    700           5
# 712  646        KyuremWhite Kyurem    Dragon       Ice    700           5
# 713  647      KeldeoOrdinary Forme     Water  Fighting    580           5
# 714  647      KeldeoResolute Forme     Water  Fighting    580           5
# 715  648        MeloettaAria Forme    Normal   Psychic    600           5
# 716  648   MeloettaPirouette Forme    Normal  Fighting    600           5
# 717  649                  Genesect       Bug     Steel    600           5
# 718  650                   Chespin     Grass       NaN    313           6
# 719  651                 Quilladin     Grass       NaN    405           6
# 720  652                Chesnaught     Grass  Fighting    530           6
# 721  653                  Fennekin      Fire       NaN    307           6
# 722  654                   Braixen      Fire       NaN    409           6
# 723  655                   Delphox      Fire   Psychic    534           6
# 724  656                   Froakie     Water       NaN    314           6
# 725  657                 Frogadier     Water       NaN    405           6
# 726  658                  Greninja     Water      Dark    530           6
# 727  659                  Bunnelby    Normal       NaN    237           6
# 728  660                 Diggersby    Normal    Ground    423           6
# 729  661                Fletchling    Normal    Flying    278           6
# 730  662               Fletchinder      Fire    Flying    382           6
# 731  663                Talonflame      Fire    Flying    499           6
# 732  664                Scatterbug       Bug       NaN    200           6
# 733  665                    Spewpa       Bug       NaN    213           6
# 734  666                  Vivillon       Bug    Flying    411           6
# 735  667                    Litleo      Fire    Normal    369           6
# 736  668                    Pyroar      Fire    Normal    507           6
# 737  669                   Flabébé     Fairy       NaN    303           6
# 738  670                   Floette     Fairy       NaN    371           6
# 739  671                   Florges     Fairy       NaN    552           6
# 740  672                    Skiddo     Grass       NaN    350           6
# 741  673                    Gogoat     Grass       NaN    531           6
# 742  674                   Pancham  Fighting       NaN    348           6
# 743  675                   Pangoro  Fighting      Dark    495           6
# 744  676                   Furfrou    Normal       NaN    472           6
# 745  677                    Espurr   Psychic       NaN    355           6
# 746  678              MeowsticMale   Psychic       NaN    466           6
# 747  678            MeowsticFemale   Psychic       NaN    466           6
# 748  679                   Honedge     Steel     Ghost    325           6
# 749  680                  Doublade     Steel     Ghost    448           6
#
#      Legendary   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 700       True   91     129       90       72       90    108
# 701       True   91      90       72       90      129    108
# 702       True   79     115       70      125       80    111
# 703       True   79     100       80      110       90    121
# 704       True   79     115       70      125       80    111
# 705       True   79     105       70      145       80    101
# 706       True  100     120      100      150      120     90
# 707       True  100     150      120      120      100     90
# 708       True   89     125       90      115       80    101
# 709       True   89     145       90      105       80     91
# 710       True  125     130       90      130       90     95
# 711       True  125     170      100      120       90     95
# 712       True  125     120       90      170      100     95
# 713      False   91      72       90      129       90    108
# 714      False   91      72       90      129       90    108
# 715      False  100      77       77      128      128     90
# 716      False  100     128       90       77       77    128
# 717      False   71     120       95      120       95     99
# 718      False   56      61       65       48       45     38
# 719      False   61      78       95       56       58     57
# 720      False   88     107      122       74       75     64
# 721      False   40      45       40       62       60     60
# 722      False   59      59       58       90       70     73
# 723      False   75      69       72      114      100    104
# 724      False   41      56       40       62       44     71
# 725      False   54      63       52       83       56     97
# 726      False   72      95       67      103       71    122
# 727      False   38      36       38       32       36     57
# 728      False   85      56       77       50       77     78
# 729      False   45      50       43       40       38     62
# 730      False   62      73       55       56       52     84
# 731      False   78      81       71       74       69    126
# 732      False   38      35       40       27       25     35
# 733      False   45      22       60       27       30     29
# 734      False   80      52       50       90       50     89
# 735      False   62      50       58       73       54     72
# 736      False   86      68       72      109       66    106
# 737      False   44      38       39       61       79     42
# 738      False   54      45       47       75       98     52
# 739      False   78      65       68      112      154     75
# 740      False   66      65       48       62       57     52
# 741      False  123     100       62       97       81     68
# 742      False   67      82       62       46       48     43
# 743      False   95     124       78       69       71     58
# 744      False   75      80       60       65       90    102
# 745      False   62      48       54       63       60     68
# 746      False   74      48       76       83       81    104
# 747      False   74      48       76       83       81    104
# 748      False   45      80      100       35       37     28
# 749      False   59     110      150       45       49     35
#  chunk df
#        #                   Name    Type 1   Type 2  Total  Generation  \
# 750  681   AegislashBlade Forme     Steel    Ghost    520           6
# 751  681  AegislashShield Forme     Steel    Ghost    520           6
# 752  682               Spritzee     Fairy      NaN    341           6
# 753  683             Aromatisse     Fairy      NaN    462           6
# 754  684                Swirlix     Fairy      NaN    341           6
# 755  685               Slurpuff     Fairy      NaN    480           6
# 756  686                  Inkay      Dark  Psychic    288           6
# 757  687                Malamar      Dark  Psychic    482           6
# 758  688                Binacle      Rock    Water    306           6
# 759  689             Barbaracle      Rock    Water    500           6
# 760  690                 Skrelp    Poison    Water    320           6
# 761  691               Dragalge    Poison   Dragon    494           6
# 762  692              Clauncher     Water      NaN    330           6
# 763  693              Clawitzer     Water      NaN    500           6
# 764  694             Helioptile  Electric   Normal    289           6
# 765  695              Heliolisk  Electric   Normal    481           6
# 766  696                 Tyrunt      Rock   Dragon    362           6
# 767  697              Tyrantrum      Rock   Dragon    521           6
# 768  698                 Amaura      Rock      Ice    362           6
# 769  699                Aurorus      Rock      Ice    521           6
# 770  700                Sylveon     Fairy      NaN    525           6
# 771  701               Hawlucha  Fighting   Flying    500           6
# 772  702                Dedenne  Electric    Fairy    431           6
# 773  703                Carbink      Rock    Fairy    500           6
# 774  704                  Goomy    Dragon      NaN    300           6
# 775  705                Sliggoo    Dragon      NaN    452           6
# 776  706                 Goodra    Dragon      NaN    600           6
# 777  707                 Klefki     Steel    Fairy    470           6
# 778  708               Phantump     Ghost    Grass    309           6
# 779  709              Trevenant     Ghost    Grass    474           6
# 780  710  PumpkabooAverage Size     Ghost    Grass    335           6
# 781  710    PumpkabooSmall Size     Ghost    Grass    335           6
# 782  710    PumpkabooLarge Size     Ghost    Grass    335           6
# 783  710    PumpkabooSuper Size     Ghost    Grass    335           6
# 784  711  GourgeistAverage Size     Ghost    Grass    494           6
# 785  711    GourgeistSmall Size     Ghost    Grass    494           6
# 786  711    GourgeistLarge Size     Ghost    Grass    494           6
# 787  711    GourgeistSuper Size     Ghost    Grass    494           6
# 788  712               Bergmite       Ice      NaN    304           6
# 789  713                Avalugg       Ice      NaN    514           6
# 790  714                 Noibat    Flying   Dragon    245           6
# 791  715                Noivern    Flying   Dragon    535           6
# 792  716                Xerneas     Fairy      NaN    680           6
# 793  717                Yveltal      Dark   Flying    680           6
# 794  718       Zygarde50% Forme    Dragon   Ground    600           6
# 795  719                Diancie      Rock    Fairy    600           6
# 796  719    DiancieMega Diancie      Rock    Fairy    700           6
# 797  720    HoopaHoopa Confined   Psychic    Ghost    600           6
# 798  720     HoopaHoopa Unbound   Psychic     Dark    680           6
# 799  721              Volcanion      Fire    Water    600           6
#
#      Legendary   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 750      False   60     150       50      150       50     60
# 751      False   60      50      150       50      150     60
# 752      False   78      52       60       63       65     23
# 753      False  101      72       72       99       89     29
# 754      False   62      48       66       59       57     49
# 755      False   82      80       86       85       75     72
# 756      False   53      54       53       37       46     45
# 757      False   86      92       88       68       75     73
# 758      False   42      52       67       39       56     50
# 759      False   72     105      115       54       86     68
# 760      False   50      60       60       60       60     30
# 761      False   65      75       90       97      123     44
# 762      False   50      53       62       58       63     44
# 763      False   71      73       88      120       89     59
# 764      False   44      38       33       61       43     70
# 765      False   62      55       52      109       94    109
# 766      False   58      89       77       45       45     48
# 767      False   82     121      119       69       59     71
# 768      False   77      59       50       67       63     46
# 769      False  123      77       72       99       92     58
# 770      False   95      65       65      110      130     60
# 771      False   78      92       75       74       63    118
# 772      False   67      58       57       81       67    101
# 773      False   50      50      150       50      150     50
# 774      False   45      50       35       55       75     40
# 775      False   68      75       53       83      113     60
# 776      False   90     100       70      110      150     80
# 777      False   57      80       91       80       87     75
# 778      False   43      70       48       50       60     38
# 779      False   85     110       76       65       82     56
# 780      False   49      66       70       44       55     51
# 781      False   44      66       70       44       55     56
# 782      False   54      66       70       44       55     46
# 783      False   59      66       70       44       55     41
# 784      False   65      90      122       58       75     84
# 785      False   55      85      122       58       75     99
# 786      False   75      95      122       58       75     69
# 787      False   85     100      122       58       75     54
# 788      False   55      69       85       32       35     28
# 789      False   95     117      184       44       46     28
# 790      False   40      30       35       45       40     55
# 791      False   85      70       80       97       80    123
# 792       True  126     131       95      131       98     99
# 793       True  126     131       95      131       98     99
# 794       True  108     100      121       81       95     95
# 795       True   50     100      150      100      150     50
# 796       True   50     160      110      160      110    110
# 797       True   80     110       60      150      130     70
# 798       True   80     160       60      170      130     80
# 799       True   80     110      120      130       90     70

# %%
# new_df=pd.DataFrame(columns=df.columns)
for df in pd.read_csv('modified.csv', chunksize=50):
    results = df.groupby(['Type 1']) .count()
    new_df=pd.concat([new_df,results])
new_df
# Out:
#          # Name Type 1 Type 2 Total Generation Legendary HP Attack Defense  \
# Fire     1    1    NaN      0     1          1         1  1      1       1
# Grass    4    4    NaN      4     4          4         4  4      4       4
# Fire     4    4    NaN      3     4          4         4  4      4       4
# Water    1    1    NaN      0     1          1         1  1      1       1
# Bug      2    2    NaN      0     2          2         2  2      2       2
# ...     ..  ...    ...    ...   ...        ...       ... ..    ...     ...
# Poison   2    2    NaN      2     2          2         2  2      2       2
# Psychic  2    2    NaN      2     2          2         2  2      2       2
# Rock     9    9    NaN      9     9          9         9  9      9       9
# Steel    3    3    NaN      3     3          3         3  3      3       3
# Water    2    2    NaN      0     2          2         2  2      2       2
#
#         Sp. Atk Sp. Def Speed
# Fire          1       1     1
# Grass         4       4     4
# Fire          4       4     4
# Water         1       1     1
# Bug           2       2     2
# ...         ...     ...   ...
# Poison        2       2     2
# Psychic       2       2     2
# Rock          9       9     9
# Steel         3       3     3
# Water         2       2     2
#
# [3254 rows x 13 columns]
