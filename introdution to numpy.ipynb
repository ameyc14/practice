# %%
import numpy as np

# %%
a= np.array([1,3,4])

# %%
print(a)
# Out:
# [1 3 4]

# %%
l1=([2,3,4], [2,3])
print(l1)
# Out:
# ([2, 3, 4], [2, 3])

# %%
l2.np.array([2,3],[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 l2.np.array([2,3],[2])
#
# NameError: name 'l2' is not defined
